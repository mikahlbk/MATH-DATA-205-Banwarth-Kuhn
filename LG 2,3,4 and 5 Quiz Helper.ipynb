# %% [markdown]
# <h1 style="text-align: center;"><b>LG 2,3,4 and 5 Quiz Helper</b></h1>

# %% [markdown]
# ### Dot Products

# %%
#define the vectors
#vector_name = [v_1,v_2]
u = [???, ???]
v = [???, ???]

#define a variable to hold the outcome
#dot_product = u_1v_1+ u_2v_2
dot_product = u[0]*v[0] + u[1]*v[1]#why python,why???

#print result
print("Manual dot product = ",dot_product)

#we can also use a built-in Python function
#to use functions we load libraries
import numpy as np
dot_product_func = np.dot(u, v)
print("Function dot product =",dot_product_func)
# Out:
#   Cell In[4], line 3
#     u = [???, ???]
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Linear Combinations

# %%
import sympy as sp

# Define unknowns
alpha, beta = sp.symbols('alpha beta')

# Define equations
eq1 = sp.Eq(???, ???)
eq2 = sp.Eq(???, ???)

# Solve system
solution = sp.solve((eq1, eq2), (alpha, beta))

print(solution)
# Out:
#   Cell In[5], line 7
#     eq1 = sp.Eq(???, ???)
#                 ^
# SyntaxError: invalid syntax
